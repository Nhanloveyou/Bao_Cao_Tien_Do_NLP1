# %%
pip install transformers

# %%
# !pip3 install sentencepiece
# !pip3 install tf_sentencepiece

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Kỹ thuật lập trình Python/Code_Python/DA')

from libary import  libary
from load_data import  load
from  buil_model import  buil
from  tranning import  train

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Kỹ thuật lập trình Python/Code_Python/Final Code')

from LoadData import processing_data

from LoadData import load_data as load
# Out:
# TF version 2.4.1
#        textID  ... sentiment
# 0  cb774db0d1  ...   neutral
# 1  549e992a42  ...  negative
# 2  088c60f138  ...  negative
# 3  9642c003ef  ...  negative
# 4  358bd9e861  ...  negative
#
# [5 rows x 4 columns]

# %%
print(load.train.head())
# Out:
#        textID  ... sentiment
# 0  cb774db0d1  ...   neutral
# 1  549e992a42  ...  negative
# 2  088c60f138  ...  negative
# 3  9642c003ef  ...  negative
# 4  358bd9e861  ...  negative
#
# [5 rows x 4 columns]

# %%
from BuildModel import build as b

x = b.Model1( 1, 96)
x.build_model()
# Out:
# All model checkpoint layers were used when initializing TFRobertaModel.
#
# All the layers of TFRobertaModel were initialized from the model checkpoint at /content/drive/MyDrive/Do_An_Python/Dataset/pretrained-roberta-base.h5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:AutoGraph could not transform <bound method Socket.send of <zmq.sugar.socket.Socket object at 0x7fd709c4cde0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module, class, method, function, traceback, frame, or code object was expected, got cython_function_or_method
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Socket.send of <zmq.sugar.socket.Socket object at 0x7fd709c4cde0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module, class, method, function, traceback, frame, or code object was expected, got cython_function_or_method
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function wrap at 0x7fd7254f9d40> and will run it as-is.
# Cause: while/else statement not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function wrap at 0x7fd7254f9d40> and will run it as-is.
# Cause: while/else statement not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# (<tensorflow.python.keras.engine.functional.Functional at 0x7fd60ade9190>,
#  <tensorflow.python.keras.engine.functional.Functional at 0x7fd60b000110>)

# %%
from Trainning import train_model

# %%
from Library import library as l
print('>>>> OVERALL 5Fold CV Jaccard =',l.np.mean(jac))
print(jac) # Jaccard CVs

# %%
from Library import library as l




class Visual():
    def __init__(self):
        pass

    def visualTrain(self):
        all = []
        start = []
        end = []
        start_pred = []
        end_pred = []
        for k in range(input_ids.shape[0]):
            a = np.argmax(preds_start_train[k,])
            b = np.argmax(preds_end_train[k,])
            start.append(np.argmax(start_tokens[k]))
            end.append(np.argmax(end_tokens[k]))        
            if a>b:
                st = train.loc[k,'text']
                start_pred.append(0)
                end_pred.append(len(st))
            else:
                text1 = " "+" ".join(train.loc[k,'text'].split())
                enc = tokenizer.encode(text1)
                st = tokenizer.decode(enc.ids[a-2:b-1])
                start_pred.append(a)
                end_pred.append(b)
            all.append(st)
        train['start'] = start
        train['end'] = end
        train['start_pred'] = start_pred
        train['end_pred'] = end_pred
        train['selected_text_pred'] = all
        train.sample(10)

        def summary():
            return train.summary()

# %%
from Library import library as l

class Menu():
    def __init__(self):
        pass
    
    def shape(self):
        return train.shape(), test.shape()

    def traindata(self):
        return train.head()

    def testdata(self):
        return test.head()

    def buildModel(self):
        return super().buildModel()
    
    def accuracy(self):
        return 
    def muc5(self):
        pass
    def muc6(self):
        pass
    def muc7(self):
        pass
    def muc8(self):
        pass
    def muc9(self):
        pass
    def muc10(self):
        pass
    def menu(self):
        print('===============================MENU===============================')
        print('---------------< Mời bạn chọn tính năng >-------------------------')
        print('1. Load dữ liệu lên')
        print('2. Xem kích thước tập train, tập test')
        print('3. Xem bộ dữ liệu train')
        print('4. Xem bộ dữ liệu test')
        print('5. Xây dựng mô hình')
        print('6. Đánh giá độ chính xác')
        print('7. Kết quả dự đoán trên tập test')
        print('8. Kết quả dự đoán trên tập train')
        print('9. Trực quan hóa thành Word Cloud')
        print('10. Trực quan hóa tỉ lệ dự đoán')
        print('11. Thống kê bộ dữ liệu train')
        print('12. Chạy thử trên 1 câu tự nhập')
        print('13. Chạy thử trên một bộ DataFrame')
        print('14. Lưu kết quả dưới dạng file csv')
        print('15. Kết thúc chương trình WITH LOVE')
        print('---------------< Mời bạn chọn tính năng >-------------------------')
        print('============================THE END===============================')

# %%
ime = input("Enter your name: \n\n")

for c in ime:

    c = c.upper()
    if (c == "A"):
        print("..######..\n..#....#..\n..######..\n..#....#..\n..#....#..\n\n")
    elif (c == "B"):
        print("..######..\n..#....#..\n..#####...\n..#....#..\n..######..\n\n")
    elif (c == "C"):
        print("..######..\n..#.......\n..#.......\n..#.......\n..######..\n\n")
    elif (c == "D"):
        print("..#####...\n..#....#..\n..#....#..\n..#....#..\n..#####...\n\n")
    elif (c == "E"):
        print("..######..\n..#.......\n..#####...\n..#.......\n..######..\n\n")
    elif (c == "F"):
        print("..######..\n..#.......\n..#####...\n..#.......\n..#.......\n\n")
    elif (c == "G"):
        print("..######..\n..#.......\n..#####...\n..#....#..\n..#####...\n\n")
    elif (c == "H"):
        print("..#....#..\n..#....#..\n..######..\n..#....#..\n..#....#..\n\n")
    elif (c == "I"):
        print("..######..\n....##....\n....##....\n....##....\n..######..\n\n")
    elif (c == "J"):
        print("..######..\n....##....\n....##....\n..#.##....\n..####....\n\n")
    elif (c == "K"):
        print("..#...#...\n..#..#....\n..##......\n..#..#....\n..#...#...\n\n")
    elif (c == "L"):
        print("..#.......\n..#.......\n..#.......\n..#.......\n..######..\n\n")
    elif (c == "M"):
        print("..#....#..\n..##..##..\n..#.##.#..\n..#....#..\n..#....#..\n\n")
    elif (c == "N"):
        print("..#....#..\n..##...#..\n..#.#..#..\n..#..#.#..\n..#...##..\n\n")
    elif (c == "O"):
        print("..######..\n..#....#..\n..#....#..\n..#....#..\n..######..\n\n")
    elif (c == "P"):
        print("..######..\n..#....#..\n..######..\n..#.......\n..#.......\n\n")
    elif (c == "Q"):
        print("..######..\n..#....#..\n..#.#..#..\n..#..#.#..\n..######..\n\n")
    elif (c == "R"):
        print("..######..\n..#....#..\n..#.##...\n..#...#...\n..#....#..\n\n")
    elif (c == "S"):
        print("..######..\n..#.......\n..######..\n.......#..\n..######..\n\n")
    elif (c == "T"):
        print("..######..\n....##....\n....##....\n....##....\n....##....\n\n")
    elif (c == "U"):
        print("..#....#..\n..#....#..\n..#....#..\n..#....#..\n..######..\n\n")
    elif (c == "V"):
        print("..#....#..\n..#....#..\n..#....#..\n...#..#...\n....##....\n\n")
    elif (c == "W"):
        print("..#....#..\n..#....#..\n..#.##.#..\n..##..##..\n..#....#..\n\n")
    elif (c == "X"):
        print("..#....#..\n...#..#...\n....##....\n...#..#...\n..#....#..\n\n")
    elif (c == "Y"):
        print("..#....#..\n...#..#...\n....##....\n....##....\n....##....\n\n")
    elif (c == "Z"):
        print("..######..\n......#...\n.....#....\n....#.....\n..######..\n\n")
    elif (c == " "):
        print("..........\n..........\n..........\n..........\n\n")
    elif (c == "."):
        print("----..----\n\n")
    elif (c == "<" and )

# %%
print('    ▀██▀─▄███▄─▀██─██▀██▀▀█')
print('    ─██─███─███─██─██─██▄█')
print('    ─██─▀██▄██▀─▀█▄█▀─██▀█')
print('    ▄██▄▄█▀▀▀─────▀──▄██▄▄█')
# Out:
# ▀██▀─▄███▄─▀██─██▀██▀▀█
# ─██─███─███─██─██─██▄█
# ─██─▀██▄██▀─▀█▄█▀─██▀█
# ▄██▄▄█▀▀▀─────▀──▄██▄▄█

# %%
def menu1():
    pass

def menu1():
    pass

def menu1():
    pass

def menu1():
    pass

def menu1():
    pass

def menu1():
    pass

def menu1():
    pass


while True:
    select = int(input())
    print('===============================MENU===============================')
    print('------------< Mời bạn chọn tính năng với số tương ứng >-----------')
    print('||                                                               ||')
    print('||   1.  Load dữ liệu lên                                        ||')
    print('||   2.  Xem kích thước tập train, tập test                      ||')
    print('||   3.  Xem bộ dữ liệu train                                    ||')
    print('||   4.  Xem bộ dữ liệu test                                     ||')
    print('||   5.  Xây dựng mô hình                                        ||')
    print('||   6.  Đánh giá độ chính xác                                   ||')
    print('||   7.  Kết quả dự đoán trên tập test                           ||')
    print('||   8.  Kết quả dự đoán trên tập train                          ||')
    print('||   9.  Trực quan hóa thành Word Cloud                          ||')
    print('||   10. Trực quan hóa tỉ lệ dự đoán                             ||')
    print('||   11. Thống kê bộ dữ liệu train                               ||')
    print('||   12. Chạy thử trên 1 câu tự nhập                             ||')
    print('||   13. Chạy thử trên một bộ DataFrame                          ||')
    print('||   14. Lưu kết quả dưới dạng file csv                          ||')
    print('||   15. Kết thúc chương trình WITH LOVE                         ||')
    print('||                                                               ||')
    print('---------< Nhập ký tự bất kỳ để kết thúc chương trình >-----------')
    print('============================THE END===============================')
    if x == 1:
# Out:
# 10
# ===============================MENU===============================
# ------------< Mời bạn chọn tính năng với số tương ứng >-----------
#
# ||   1.  Load dữ liệu lên                                        ||
# ||   2.  Xem kích thước tập train, tập test                      ||
# ||   3.  Xem bộ dữ liệu train                                    ||
# ||   4.  Xem bộ dữ liệu test                                     ||
# ||   5.  Xây dựng mô hình                                        ||
# ||   6.  Đánh giá độ chính xác                                   ||
# ||   7.  Kết quả dự đoán trên tập test                           ||
# ||   8.  Kết quả dự đoán trên tập train                          ||
# ||   9.  Trực quan hóa thành Word Cloud                          ||
# ||   10. Trực quan hóa tỉ lệ dự đoán                             ||
# ||   11. Thống kê bộ dữ liệu train                               ||
# ||   12. Chạy thử trên 1 câu tự nhập                             ||
# ||   13. Chạy thử trên một bộ DataFrame                          ||
# ||   14. Lưu kết quả dưới dạng file csv                          ||
# ||   15. Kết thúc chương trình WITH LOVE                         ||
# ||                                                               ||
# ---------< Nhập ký tự bất kỳ để kết thúc chương trình >-----------
# ============================THE END===============================
